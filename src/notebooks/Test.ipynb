# %%
from ..modules import preprocessing
import polars as pl

dtypes = {
    'user_name':pl.Utf8,
    'user_location':pl.Utf8,
    'user_description':pl.Utf8,
    'user_created':pl.Utf8,
    'user_followers':pl.Utf8,
    'user_friends':pl.Utf8,
    'user_favourites':pl.Utf8,
    'user_verified':pl.Utf8,
    'date':pl.Utf8,
    'text':pl.Utf8,
    'hashtags':pl.Utf8,
    'source':pl.Utf8,
    'is_retweet':pl.Utf8
}
encode = 'Utf8'
df = pl.read_csv("../data/F1_tweets.csv", dtypes=dtypes, encoding=encode)
for i in range(10):
    print(f"Original: {df['text'][i]}")
    print(f"Preprocessed: {preprocessing.text_preprocessing(df['text'][i])}")
    print("\n######################################################################\n")
# Out:
# Original: The next great #F1 duo!!! @ESPNF1 https://t.co/WMhaoAdSxF
# Preprocessed: next great hashtag f1 duo mention espnf1 co wmhaoadsxf
#
# ######################################################################
#
# Original: @F1 What if…Hamilton would have gone to the pit…empty grid for a start?!🤔 something to think about #HungarianGP #F1
# Preprocessed: mention f1 hamilton would gone pit empty grid start thinking_face something think hashtag hungariangp hashtag f1
#
# ######################################################################
#
# Original: This has been a tiring #f1 day... https://t.co/34ggWgAlT6
# Preprocessed: tiring hashtag f1 day co 34ggwgalt6
#
# ######################################################################
#
# Original: Valteri Bottass tracking down Max Verstappen on the way home
#
# #F1 https://t.co/epTHlDyjU6
# Preprocessed: valteri bottass tracking max verstappen way home hashtag f1 co epthldyju6
#
# ######################################################################
#
# Original: No words to describe the #HungarianGP so I will just say it was a fantastic shit race
#
# Vettel deserved P2
# Ham shunning all the haters w/ the 6pt lead
# ALO-HAM battle on repeat
# Congrats Ocon
# I am still grieving for Lando’s broken streak
#
# #F1
# Preprocessed: word describe hashtag hungariangp say fantastic shit race vettel deserved p2 ham shunning hater w 6pt lead alo ham battle repeat congrats ocon still grieving lando broken streak hashtag f1
#
# ######################################################################
#
# Original: SEB SAID LGBTQ+ RIGHTS!! #F1 #LGBTQ https://t.co/25NqrgN3my
# Preprocessed: seb said lgbtq right hashtag f1 hashtag lgbtq co 25nqrgn3my
#
# ######################################################################
#
# Original: Do they remove Ocon too? Ham to be first.
# This is the grand-prix for Mercedes to Mercedes by Mercedes.
#
# #SebastianVettel #EstebanOcon
# #f1 #HungarianGP #HungaryGP
# Preprocessed: remove ocon ham first grand prix mercedes mercedes mercedes hashtag sebastianvettel hashtag estebanocon hashtag f1 hashtag hungariangp hashtag hungarygp
#
# ######################################################################
#
# Original: Breaking news FIA has disqualified  @OconEsteban for running down the pit lane too fast @LewisHamilton takes the win #F1 #HungaryGP #BREAKINGNEWS #FIA
# Preprocessed: breaking news fia disqualified mention oconesteban running pit lane fast mention lewishamilton take win hashtag f1 hashtag hungarygp hashtag breakingnews hashtag fia
#
# ######################################################################
#
# Original: VIDEO—"They can disqualify me if they want"-Sebastian Vettel, who wore a Same Love shirt for pre-race and rainbow mask for post-race interviews to defy anti-#LGBT edicts of Hungary PM Viktor Orbán | #HungarianGP #F1 https://t.co/UU0PPCUT6K via @YouTube
# Preprocessed: video disqualify want sebastian vettel wore love shirt pre race rainbow mask post race interview defy anti hashtag lgbt edict hungary prime minister viktor orbán hashtag hungariangp hashtag f1 co uu0ppcut6k via mention youtube
#
# ######################################################################
#
# Original: #NowPlaying on https://t.co/5L1U2uVCQV Downforce Radio - Episode 6: Motoring Pride and Larking About
#
# The Nation's Motorsport Station!! #radio #motorsport #f1 #btcc #racing #music #cars https://t.co/PIjC5niHw3
# Preprocessed: hashtag nowplaying co 5l1u2uvcqv downforce radio episode 6 motoring pride larking nation motorsport station hashtag radio hashtag motorsport hashtag f1 hashtag btcc hashtag racing hashtag music hashtag car co pijc5nihw3
#
# ######################################################################
